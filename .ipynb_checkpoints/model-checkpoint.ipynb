# %%
# !pip install transformers datasets torch --break-system-packages
from transformers import (
    AutoModelForQuestionAnswering,
    AutoTokenizer,
    AutoModelForSeq2SeqLM,
    pipeline,
    TrainingArguments,
    Trainer,
    DefaultDataCollator,
)
import torch
from datasets import load_dataset
import argparse
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /home/anurag/.local/lib/python3.12/site-packages (4.45.2)
# Requirement already satisfied: datasets in /home/anurag/.local/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: torch in /home/anurag/.local/lib/python3.12/site-packages (2.4.1)
# Requirement already satisfied: filelock in /usr/lib/python3.12/site-packages (from transformers) (3.13.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/anurag/.local/lib/python3.12/site-packages (from transformers) (0.25.2)
# Requirement already satisfied: numpy>=1.17 in /home/anurag/.local/lib/python3.12/site-packages (from transformers) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.12/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3.12/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/anurag/.local/lib/python3.12/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/lib/python3.12/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/anurag/.local/lib/python3.12/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /home/anurag/.local/lib/python3.12/site-packages (from transformers) (0.20.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/lib/python3.12/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/anurag/.local/lib/python3.12/site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/anurag/.local/lib/python3.12/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/anurag/.local/lib/python3.12/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: xxhash in /home/anurag/.local/lib/python3.12/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /home/anurag/.local/lib/python3.12/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /home/anurag/.local/lib/python3.12/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /home/anurag/.local/lib/python3.12/site-packages (from datasets) (3.10.10)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /home/anurag/.local/lib/python3.12/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /home/anurag/.local/lib/python3.12/site-packages (from torch) (3.4.1)
# Requirement already satisfied: jinja2 in /usr/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: setuptools in /usr/lib/python3.12/site-packages (from torch) (69.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/anurag/.local/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/anurag/.local/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/anurag/.local/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/anurag/.local/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/anurag/.local/lib/python3.12/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/anurag/.local/lib/python3.12/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/anurag/.local/lib/python3.12/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/anurag/.local/lib/python3.12/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/anurag/.local/lib/python3.12/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/anurag/.local/lib/python3.12/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/anurag/.local/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/anurag/.local/lib/python3.12/site-packages (from torch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/anurag/.local/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.77)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/anurag/.local/lib/python3.12/site-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/anurag/.local/lib/python3.12/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3.12/site-packages (from aiohttp->datasets) (23.2.1.dev0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/anurag/.local/lib/python3.12/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/anurag/.local/lib/python3.12/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/anurag/.local/lib/python3.12/site-packages (from aiohttp->datasets) (1.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/lib/python3.12/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.12/site-packages (from requests->transformers) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3.12/site-packages (from requests->transformers) (1.26.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3.12/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/lib/python3.12/site-packages (from pandas->datasets) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3.12/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/anurag/.local/lib/python3.12/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: platformdirs in /usr/lib/python3.12/site-packages (from setuptools->torch) (4.2.2)
# Requirement already satisfied: jaraco.text in /usr/lib/python3.12/site-packages (from setuptools->torch) (4.0.0)
# Requirement already satisfied: more-itertools in /usr/lib/python3.12/site-packages (from setuptools->torch) (10.3.0)
# Requirement already satisfied: ordered-set in /usr/lib/python3.12/site-packages (from setuptools->torch) (4.1.0)
# Requirement already satisfied: tomli in /usr/lib/python3.12/site-packages (from setuptools->torch) (2.0.1)
# Requirement already satisfied: validate-pyproject in /usr/lib/python3.12/site-packages (from setuptools->torch) (0.19)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/anurag/.local/lib/python3.12/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/anurag/.local/lib/python3.12/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Requirement already satisfied: jaraco.functools in /usr/lib/python3.12/site-packages (from jaraco.text->setuptools->torch) (4.0.2)
# Requirement already satisfied: jaraco.context>=4.1 in /usr/lib/python3.12/site-packages (from jaraco.text->setuptools->torch) (5.3.0)
# Requirement already satisfied: autocommand in /usr/lib/python3.12/site-packages (from jaraco.text->setuptools->torch) (2.2.2)
# Requirement already satisfied: fastjsonschema<=3,>=2.16.2 in /usr/lib/python3.12/site-packages (from validate-pyproject->setuptools->torch) (2.20.0)

# %%
def load_qa_model(model_name="deepset/roberta-base-squad2"):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForQuestionAnswering.from_pretrained(model_name).to(device)
    return model, tokenizer

# %%
def load_summarization_model(model_name="facebook/bart-large-cnn"):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSeq2SeqLM.from_pretrained(model_name).to(device)
    return model, tokenizer

# %%
def preprocess_squad(examples, tokenizer):
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=384,
        truncation="only_second",
        return_offsets_mapping=True,
        padding="max_length",
    )

    offset_mapping = inputs.pop("offset_mapping")
    answers = examples["answers"]
    start_positions = []
    end_positions = []

    for i, offset in enumerate(offset_mapping):
        answer = answers[i]
        start_char = answer["answer_start"][0]
        end_char = answer["answer_start"][0] + len(answer["text"][0])
        sequence_ids = inputs.sequence_ids(i)
        idx = 0
        while sequence_ids[idx] != 1:
            idx += 1
        context_start = idx
        while sequence_ids[idx] == 1:
            idx += 1
        context_end = idx - 1

        if offset[context_start][0] > end_char or offset[context_end][1] < start_char:
            start_positions.append(0)
            end_positions.append(0)
        else:
            idx = context_start
            while idx <= context_end and offset[idx][0] <= start_char:
                idx += 1
            start_positions.append(idx - 1)

            idx = context_end
            while idx >= context_start and offset[idx][1] >= end_char:
                idx -= 1
            end_positions.append(idx + 1)

    inputs["start_positions"] = start_positions
    inputs["end_positions"] = end_positions
    return inputs

# %%
def train_qa(model, tokenizer, train_size=10000, eval_size=5000, epochs=1):
    squad = load_dataset("squad")
    tokenized_squad = squad.map(
        lambda examples: preprocess_squad(examples, tokenizer),
        batched=True,
        remove_columns=squad["train"].column_names
    )

    train_dataset = tokenized_squad["train"].select(range(train_size))
    eval_dataset = tokenized_squad["validation"].select(range(eval_size))

    training_args = TrainingArguments(
        output_dir="./results",
        evaluation_strategy="epoch",
        learning_rate=2e-5,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        num_train_epochs=epochs,
        weight_decay=0.01,
        fp16=True,
        report_to=[],
    )

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        tokenizer=tokenizer,
        data_collator=DefaultDataCollator(),
    )

    trainer.train()
    return model

# %%
def get_answer(qa_pipeline, question, context):
    qa_input = {
        'question': question,
        'context': context
    }
    return qa_pipeline(qa_input)

# %%
def summarize_text(summarizer, text, max_length=130, min_length=30):
    return summarizer(text, max_length=max_length, min_length=min_length, do_sample=False)[0]['summary_text']

# %%
def main():
    qa_model, qa_tokenizer = load_qa_model()
    summarization_model, summarization_tokenizer = load_summarization_model()

    qa_pipeline = pipeline('question-answering', model=qa_model, tokenizer=qa_tokenizer, device=0 if torch.cuda.is_available() else -1)
    summarizer = pipeline("summarization", model=summarization_model, tokenizer=summarization_tokenizer, device=0 if torch.cuda.is_available() else -1)
    qa_pipeline.save_pretrained('./qa_model')
    while True:
        print("\nChoose an option:")
        print("1. Ask a question")
        print("2. Summarize text")
        print("3. Exit")

        choice = input("Enter your choice (1/2/3): ")

        if choice == '1':
            context = input("Enter the context: ")
            question = input("Enter your question: ")
            answer = get_answer(qa_pipeline, question, context)
            print(f"Answer: {answer['answer']}")
            print(f"Confidence: {answer['score']:.2f}")

        elif choice == '2':
            text = input("Enter the text to summarize: ")
            summary = summarize_text(summarizer, text)
            print(f"Summary: {summary}")

        elif choice == '3':
            print("Goodbye!")
            break

        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# Choose an option:
# 1. Ask a question
# 2. Summarize text
# 3. Exit
# Enter your choice (1/2/3):  2
# Enter the text to summarize:  what the hell
# Your max_length is set to 130, but your input_length is only 5. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=2)
# Summary: CNN.com will feature iReporter photos in a weekly Travel Snapshots gallery. Please submit your best shots of the U.S. for next week. Visit CNN.com/Travel next Wednesday for a new gallery of snapshots.
#
# Choose an option:
# 1. Ask a question
# 2. Summarize text
# 3. Exit
# Enter your choice (1/2/3):  If you want to handle two branches with unrelated histories and you're trying to rebase or merge them, Git provides options to manage this. Here's how you can handle it depending on the action you want to perform:  ### 1. **Merging two branches with unrelated histories** If you want to merge two branches that have completely unrelated histories, Git will throw an error by default. You can force the merge using the `--allow-unrelated-histories` flag.  ```bash git checkout branch-you-want-to-merge-into git merge branch-you-want-to-merge --allow-unrelated-histories ```  This will merge the two branches, even though they don't share a common commit history.  ### 2. **Rebasing two branches with unrelated histories** If you want to rebase a branch with unrelated histories onto another, you might encounter conflicts or issues due to the lack of common ancestry. You would typically start by rebasing one branch onto the other:  ```bash git checkout branch-you-want-to-rebase git rebase --onto target-branch ```  However, if you see errors about unrelated histories, you might need to manually apply changes from one branch onto another, since `rebase` does not have a `--allow-unrelated-histories` flag like `merge` does.  ### 3. **Cherry-picking commits across branches** If you're dealing with unrelated histories but only want to bring over specific commits, you can use `cherry-pick` to apply commits from one branch to another.  ```bash git checkout target-branch git cherry-pick commit-hash-from-other-branch ```  This method works well when you don't need the full history and just want to apply certain changes from one branch to another.  These techniques should allow you to work with branches that don't share any common history.
# Invalid choice. Please try again.
#
# Choose an option:
# 1. Ask a question
# 2. Summarize text
# 3. Exit
# Enter your choice (1/2/3):  3
# Goodbye!
